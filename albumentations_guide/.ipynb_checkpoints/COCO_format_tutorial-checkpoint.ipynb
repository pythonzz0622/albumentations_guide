# %%
import os 
import json
from pycocotools.coco import COCO

# %%
os.listdir()
# Out:
# ['ref_image_mask.json',
#  'dataset.json',
#  'Pixel-level_augumentation.ipynb',
#  'ref_image.jpg',
#  'albumentation Tutorial.ipynb',
#  'Spatial-level-augmentation.ipynb',
#  '.ipynb_checkpoints',
#  'make_clssifier_layer.ipynb',
#  'Untitled.ipynb',
#  'ref_image_2.jpg']

# %%
with open("dataset.json", "r") as st_json:
    st_python = json.load(st_json)

# %%
coco = COCO("dataset.json")
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
st_python
# Out:
# {'images': [{'height': 120,
#    'width': 120,
#    'id': 1,
#    'file_name': 'ref_image.jpg'}],
#  'annotations': [{'iscrowd': 0,
#    'image_id': 1,
#    'bbox': [7, 0, 81, 100],
#    'segmentation': [[19,
#      1,
#      22,
#      24,
#      28,
#      32,
#      22,
#      33,
#      16,
#      32,
#      12,
#      37,
#      7,
#      43,
#      6,
#      56,
#      11,
#      73,
#      25,
#      81,
#      27,
#      90,
#      34,
#      100,
#      46,
#      96,
#      49,
#      84,
#      48,
#      73,
#      59,
#      79,
#      64,
#      72,
#      64,
#      58,
#      63,
#      49,
#      59,
#      48,
#      55,
#      44,
#      49,
#      48,
#      44,
#      56,
#      44,
#      64,
#      41,
#      58,
#      36,
#      58,
#      34,
#      42,
#      45,
#      33,
#      49,
#      21,
#      56,
#      17,
#      60,
#      22,
#      60,
#      37,
#      65,
#      48,
#      75,
#      49,
#      81,
#      38,
#      88,
#      29,
#      86,
#      18,
#      83,
#      7,
#      77,
#      4,
#      76,
#      0]],
#    'category_id': 0,
#    'id': 1,
#    'area': 4495},
#   {'iscrowd': 0,
#    'image_id': 1,
#    'bbox': [5, 102, 35, 17],
#    'segmentation': [[5,
#      116,
#      12,
#      113,
#      14,
#      105,
#      22,
#      102,
#      28,
#      110,
#      32,
#      104,
#      39,
#      107,
#      40,
#      119,
#      5,
#      119]],
#    'category_id': 0,
#    'id': 2,
#    'area': 391},
#   {'iscrowd': 0,
#    'image_id': 1,
#    'bbox': [87, 0, 21, 30],
#    'segmentation': [[91,
#      0,
#      94,
#      8,
#      91,
#      10,
#      91,
#      14,
#      86,
#      20,
#      92,
#      30,
#      100,
#      30,
#      104,
#      17,
#      102,
#      9,
#      106,
#      7,
#      108,
#      0,
#      93,
#      0]],
#    'category_id': 0,
#    'id': 3,
#    'area': 402},
#   {'iscrowd': 0,
#    'image_id': 1,
#    'bbox': [112, 1, 7, 31],
#    'segmentation': [[112, 1, 112, 19, 119, 32, 118, 0]],
#    'category_id': 0,
#    'id': 4,
#    'area': 153},
#   {'iscrowd': 0,
#    'image_id': 1,
#    'bbox': [78, 53, 29, 63],
#    'segmentation': [[98,
#      113,
#      105,
#      97,
#      106,
#      77,
#      104,
#      68,
#      104,
#      57,
#      99,
#      53,
#      92,
#      53,
#      83,
#      55,
#      77,
#      64,
#      79,
#      92,
#      80,
#      107,
#      86,
#      116]],
#    'category_id': 0,
#    'id': 5,
#    'area': 1465}],
#  'categories': [{'id': 0, 'name': 'tu', 'supercategory': 'tu'}]}

# %%
coco.getAnnIds(imgIds= 1 )
# Out:
# [1, 2, 3, 4, 5]

# %%
coco.getAnnIds(catIds=2)
# Out:
# []

# %%
coco.loadAnns(1)
# Out:
# [{'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [7, 0, 81, 100],
#   'segmentation': [[19,
#     1,
#     22,
#     24,
#     28,
#     32,
#     22,
#     33,
#     16,
#     32,
#     12,
#     37,
#     7,
#     43,
#     6,
#     56,
#     11,
#     73,
#     25,
#     81,
#     27,
#     90,
#     34,
#     100,
#     46,
#     96,
#     49,
#     84,
#     48,
#     73,
#     59,
#     79,
#     64,
#     72,
#     64,
#     58,
#     63,
#     49,
#     59,
#     48,
#     55,
#     44,
#     49,
#     48,
#     44,
#     56,
#     44,
#     64,
#     41,
#     58,
#     36,
#     58,
#     34,
#     42,
#     45,
#     33,
#     49,
#     21,
#     56,
#     17,
#     60,
#     22,
#     60,
#     37,
#     65,
#     48,
#     75,
#     49,
#     81,
#     38,
#     88,
#     29,
#     86,
#     18,
#     83,
#     7,
#     77,
#     4,
#     76,
#     0]],
#   'category_id': 0,
#   'id': 1,
#   'area': 4495}]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./ref_image.jpg')
img = img[: , ::-1]
plt.imshow(img)

# %%
# load and display instance annotations
plt.imshow(img); plt.axis('off')
annIds = coco.getAnnIds(imgIds=1, catIds=0, iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns)

# %%
# load and display instance annotations
plt.imshow(img); plt.axis('off')
annIds = coco.getAnnIds(imgIds=1, catIds=0, iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns , draw_bbox = True , )

# %%
for i in range(len(coco.loadAnns(annIds))):
    temp = coco.loadAnns(annIds)[i]['bbox']
    print(temp)
# Out:
# [7, 0, 81, 100]
# [5, 102, 35, 17]
# [87, 0, 21, 30]
# [112, 1, 7, 31]
# [78, 53, 29, 63]

# %%
plt.imshow(img)

# %%
image = img.copy()

# %%
for i in range(len(coco.loadAnns(annIds))):
    temp = coco.loadAnns(annIds)[i]['bbox']
    print(temp)
    cv2.rectangle(img , (temp[0] , temp[1] + 1) , (temp[2] , temp[3]) , (255 , 255, 0) , 5)
plt.imshow(img)
# Out:
# [7, 0, 81, 100]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
#       2     temp = coco.loadAnns(annIds)[i]['bbox']
#       3     print(temp)
# ----> 4     cv2.rectangle(img , (temp[0] , temp[1] + 1) , (temp[2] , temp[3]) , (255 , 255, 0) , 5)
#       5 plt.imshow(img)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Layout of the output array img is incompatible with cv::Mat
# >  - Expected Ptr<cv::UMat> for argument 'img'
# >  - Layout of the output array img is incompatible with cv::Mat
# >  - Expected Ptr<cv::UMat> for argument 'img'
